# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('../datasets/small_examples/flettematikk.csv')

reg = LinearRegression()
reg.fit(data[['braid']],data[['thread']])

x = np.linspace(0,6,1001).reshape(-1,1)
y = reg.predict(x_test)

plt.scatter(data[['braid']],data[['thread']],c='r')
plt.plot(x,y)

plt.ylabel('Trådlengde')
plt.xlabel('Båndlengde')

plt.show()

# %%
reg.predict([[2.5]])
# Out:
# array([[ 3.4496785]])
