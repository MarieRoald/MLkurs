# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
data = pd.read_csv("../datasets/imdb-5000-movie-dataset/movie_metadata.csv")

# %%
print data.head().T
# Out:
#                                                                            0  \
# color                                                                  Color
# director_name                                                  James Cameron
# num_critic_for_reviews                                                   723
# duration                                                                 178
# director_facebook_likes                                                    0
# actor_3_facebook_likes                                                   855
# actor_2_name                                                Joel David Moore
# actor_1_facebook_likes                                                  1000
# gross                                                            7.60506e+08
# genres                                       Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                     CCH Pounder
# ...

# %%
data_use = data.ix[:,['movie_facebook_likes','gross','cast_total_facebook_likes','duration','budget']]
#data_use = data.ix[:,['duration','movie_facebook_likes']]

from sklearn import preprocessing


data_use = data_use - data_use.mean()
data_use = data_use / data_use.std()


pd.scatter_matrix(data_use)
plt.show()

X = data_use.values[:,:]


print X.shape

data_use = data_use.dropna()
X_scaled = preprocessing.scale(data_use)

#plt.scatter(X[:,0],X[:,1])
#plt.show()
# Out:
# (5043L, 5L)

# %%
print data_use.std()
# Out:
# movie_facebook_likes         2.130500e+04
# gross                        6.980668e+07
# cast_total_facebook_likes    1.892702e+04
# duration                     2.270678e+01
# budget                       2.224177e+08
# dtype: float64
